# %%
import matplotlib.pyplot as plt
import pandas as pd

def getK_N(data, row):
    val = data.iloc[row][:2].tolist()
    return "n: " + str(val[0]) + " k:" + str(val[1])

# %%
data = pd.read_csv("PSO_seed_1234_prob_1_all.csv")

# %%
data.head()
# Out:
#    n     k    loss p1    loss p2    loss p3    loss p4    loss p5    loss p6  \
# 0  5     5   2.987861   2.987941   2.987832   2.987961   2.987837   2.987832
# 1  5    50   3.549209   3.590284   3.547176   3.547205   3.547476   3.568624
# 2  5   100   5.042242   5.042260   5.042549   5.042243   5.042244   5.042437
# 3  5   500  12.377945  12.635684  12.402406  12.295075  12.488598  12.454441
# 4  5  1000   2.111695   2.108614   2.108980   2.113956   2.115749   2.109222
#
#      loss p7    loss p8  ...   loss p41   loss p42   loss p43   loss p44  \
# 0   2.988452   2.987836  ...   2.987915   2.987986   2.988233   2.987834
# 1   3.551543   3.547619  ...   3.545437   3.607299   3.561336   3.550991
# 2   5.042242   5.042262  ...   5.042773   5.042242   5.047080   5.042338
# 3  12.512895  12.313625  ...  12.693031  12.383016  12.434483  12.349728
# 4   2.167858   2.115359  ...   2.115677   2.113421   2.138312   2.109073
#
# ...

# %%
for i in range(len(data)):
    plt.violinplot(data.iloc[i][2:].tolist(), showextrema=True, showmeans=True)
    plt.title(getK_N(data,i))
    plt.show()
